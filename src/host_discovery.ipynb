# %%
import os

ruta = os.path.expanduser("~/Escritorio/P2_Reconocimiento_activo/src")
print(ruta)
print("Existe?:", os.path.exists(ruta))
# Out:
# /home/itzel/Escritorio/P2_Reconocimiento_activo/src
# Existe?: True

# %%
import sys
sys.path.insert(0, "/home/itzel/Escritorio/P2_Reconocimiento_activo/src")

from host_discovery import craft_discovery_pkts, discover_hosts

# %%
discover_hosts("icmp_timestamp", "127.0.0.1")
# Out:
# ['127.0.0.1']

# %%
discover_hosts("icmp_timestamp", "10.255.255.1")
# Out:
# []

# %%
discover_hosts(["udp", "tcp_ack", "icmp_timestamp"], "127.0.0.1")
# Out:
# ['127.0.0.1']
